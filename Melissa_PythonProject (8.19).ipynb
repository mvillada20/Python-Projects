# %% [markdown]
# ## Import packages and dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %% [markdown]
# ## Pulling the raw data. There are 212331 rows and 15 columns of information

# %%
df
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# ...

# %%
df.describe()
# Out:
#                 Year   Total Tested
# count  212331.000000  212331.000000
# mean     2015.956069      49.364200
# std         0.799726      93.023576
# min      2015.000000       1.000000
# 25%      2015.000000       5.000000
# 50%      2016.000000      20.000000
# 75%      2017.000000      57.000000
# max      2017.000000    1729.000000

# %% [markdown]
# ## Forcing non-numerical values to become NaNs on the Mean Score column. Changing NA and 'S' values to NaN.

# %%
df['Mean Score'] = pd.to_numeric(df['Mean Score'], errors = 'coerce')
df
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested  Mean Score  \
# 0               Common Core Algebra  2017             4         NaN
# 1                Living Environment  2015            16        77.9
# ...

# %% [markdown]
# ## Dropping any non-numerical value on the Mean Score column. It skewed the data, but I was able to work with only numbers, no N/A or NaN values.

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#        School DBN                     School Name School Level  \
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 5          01M140          P.S. 140 Nathan Straus          K-8
# 6          01M140          P.S. 140 Nathan Straus          K-8
# 7          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212321     84X717            Icahn Charter School          K-8
# 212322     84X717            Icahn Charter School          K-8
# 212323     84X717            Icahn Charter School          K-8
# 212324     84X717            Icahn Charter School          K-8
# 212325     84X717            Icahn Charter School          K-8
#
#                Regents Exam  Year  Total Tested  Mean Score  \
# 1        Living Environment  2015            16        77.9
# 2        Living Environment  2016             9        74.0
# ...

# %% [markdown]
# ## On line #4 you will see the descriptive statistics for the raw data, however, line #8 will display the data after the clean-up (removing NaN's from the Mean Score column). The information is a bit skewed, but I found it easier to work without them and work with only numbers.

# %%
df.describe()
# Out:
#                 Year   Total Tested     Mean Score
# count  137101.000000  137101.000000  137101.000000
# mean     2015.957630      71.584970      65.999558
# std         0.809277     107.837188      11.288937
# min      2015.000000       6.000000      15.000000
# 25%      2015.000000      18.000000      58.300000
# 50%      2016.000000      39.000000      65.400000
# 75%      2017.000000      82.000000      73.400000
# max      2017.000000    1729.000000      98.700000

# %% [markdown]
# ## I chose to research information on Francis Lewis High School, so I filtered particularily by that school name. There are 449 rows and 15 columns of information after removing the NaNs. Without removing the non-numerical values there would be 490 rows.

# %%
df1=df[df['School Name'] == 'Francis Lewis High School']
df1
# Out:
#        School DBN                School Name School Level  \
# 14549      26Q430  Francis Lewis High School  High school
# 14550      26Q430  Francis Lewis High School  High school
# 14551      26Q430  Francis Lewis High School  High school
# 14552      26Q430  Francis Lewis High School  High school
# 14553      26Q430  Francis Lewis High School  High school
# ...           ...                        ...          ...
# 194228     26Q430  Francis Lewis High School  High school
# 194229     26Q430  Francis Lewis High School  High school
# 194230     26Q430  Francis Lewis High School  High school
# 194231     26Q430  Francis Lewis High School  High school
# 194232     26Q430  Francis Lewis High School  High school
#
#                        Regents Exam  Year  Total Tested  Mean Score  \
# 14549         Algebra2/Trigonometry  2015           845        77.8
# 14550         Algebra2/Trigonometry  2016           889        76.7
# ...

# %% [markdown]
# ## I went a little further and filtered by a particular Regents Exam - U.S. History and Government.

# %%
df2=df1[df1['Regents Exam'] == 'U.S. History and Government']
df2
# Out:
#        School DBN                School Name School Level  \
# 14584      26Q430  Francis Lewis High School  High school
# 14585      26Q430  Francis Lewis High School  High school
# 14586      26Q430  Francis Lewis High School  High school
# 45553      26Q430  Francis Lewis High School  High school
# 45554      26Q430  Francis Lewis High School  High school
# 45555      26Q430  Francis Lewis High School  High school
# 45556      26Q430  Francis Lewis High School  High school
# 45557      26Q430  Francis Lewis High School  High school
# 45558      26Q430  Francis Lewis High School  High school
# 91016      26Q430  Francis Lewis High School  High school
# 91017      26Q430  Francis Lewis High School  High school
# 91018      26Q430  Francis Lewis High School  High school
# 91019      26Q430  Francis Lewis High School  High school
# 91020      26Q430  Francis Lewis High School  High school
# 91021      26Q430  Francis Lewis High School  High school
# ...

# %% [markdown]
# ## Additional descriptive statistics, but for FLHS only! I decided to use the information available for Francis Lewis High School and group by Regents Exam and Year and filtered to the max Mean Score. That is the information desplayed below; max amount of Mean Score for that particular year and regents topic. As you can see, there are all numerical values - without dropping the NaNs, there would be a bunch of 'S' shown.

# %%
df1.groupby(['Regents Exam','Year'])['Mean Score'].max()
# Out:
# Regents Exam                     Year
# Algebra2/Trigonometry            2015    81.6
#                                  2016    82.8
#                                  2017    68.8
# Common Core Algebra              2015    71.7
#                                  2016    81.5
#                                  2017    84.8
# Common Core Algebra2             2016    75.6
#                                  2017    79.3
# Common Core English              2015    82.4
#                                  2016    85.1
#                                  2017    85.6
# Common Core Geometry             2015    74.1
#                                  2016    76.4
#                                  2017    78.5
# English                          2015    80.3
#                                  2016    64.1
# Geometry                         2015    85.2
#                                  2016    70.7
# Global History and Geography     2015    79.9
#                                  2016    80.7
# ...

# %% [markdown]
# ## Below, I wanted to dive a little deeper and groupby the particular regents exam (U.S. History and Government), the year and the max Mean Score for that year.

# %%
ms=df2.groupby(['Regents Exam','Year'])['Mean Score'].max()
ms[0]
# Out:
# 85.0

# %%
ms
# Out:
# Regents Exam                 Year
# U.S. History and Government  2015    85.0
#                              2016    85.8
#                              2017    92.3
# Name: Mean Score, dtype: float64

# %% [markdown]
# ## Below is a bar graph of the above information - it is showing the max Mean Scores for the U.S. History and Government regents exams between 2015-2017 for FLHS only.

# %%
ms=ms.astype(float)
ms.plot.bar(color='red')

# %%
df['Mean Score']
# Out:
# 1         77.9
# 2         74.0
# 5         67.4
# 6         72.6
# 7         64.4
#           ...
# 212321    87.2
# 212322    87.0
# 212323    88.3
# 212324    76.5
# 212325    79.8
# Name: Mean Score, Length: 137101, dtype: float64

# %% [markdown]
# ## Below - Descriptive statistical data demonstrating the cumulative average Mean Score for the entire school's (FLHS) various Regents Exams, and sorted from highest to lowest.

# %%
flhs=df1.groupby(['School Name','Regents Exam'])['Mean Score'].mean().sort_values(ascending=False)
flhs
# Out:
# School Name                Regents Exam
# Francis Lewis High School  U.S. History and Government        81.364103
#                            Physical Settings/Physics          78.703704
#                            Living Environment                 78.551351
#                            Common Core English                77.964103
#                            Physical Settings/Chemistry        77.951351
#                            Geometry                           77.278947
#                            Global History and Geography       75.507692
#                            Common Core Algebra                73.948571
#                            Algebra2/Trigonometry              72.887097
#                            Integrated Algebra                 72.004167
#                            Common Core Algebra2               71.938462
#                            Common Core Geometry               71.667568
# ...

# %% [markdown]
# ## The below graph visually represents line 28 by using a bar graph that shows the cumulative average Mean Score for all the regents exam in FLHS.

# %%
flhs.plot.bar(color={'red','green','orange','blue'})

# %% [markdown]
# ## Below demonstrates the overall information of ALL the schools grouped by regents exam, with the max Mean Score

# %%
df.groupby(['School Name','Regents Exam'])['Mean Score'].mean().sort_values(ascending=False)
# Out:
# School Name                                         Regents Exam
# High School of American Studies at Lehman College   U.S. History and Government    97.713636
# Bronx High School of Science                        U.S. History and Government    96.752941
# Stuyvesant High School                              U.S. History and Government    96.393333
# The Math & Science Exploratory School               U.S. History and Government    96.050000
# Townsend Harris High School                         U.S. History and Government    95.790625
#                                                                                      ...
# Automotive High School                              Algebra2/Trigonometry          30.700000
# Jonathan Levin High School for Media and Communica  Algebra2/Trigonometry          26.600000
# John Adams Yabc                                     Algebra2/Trigonometry          25.900000
# ...

# %% [markdown]
# ## Forcing non-numerical values to become NaNs on the Total Tested column. Changing NA and 'S' values to NaN.

# %%
df1['Total Tested'] = pd.to_numeric(df['Total Tested'], errors = 'coerce')
df1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        School DBN                School Name School Level  \
# 14549      26Q430  Francis Lewis High School  High school
# 14550      26Q430  Francis Lewis High School  High school
# 14551      26Q430  Francis Lewis High School  High school
# 14552      26Q430  Francis Lewis High School  High school
# 14553      26Q430  Francis Lewis High School  High school
# ...           ...                        ...          ...
# 194228     26Q430  Francis Lewis High School  High school
# 194229     26Q430  Francis Lewis High School  High school
# ...

# %%
df1.dropna(inplace=True)
df1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        School DBN                School Name School Level  \
# 14549      26Q430  Francis Lewis High School  High school
# 14550      26Q430  Francis Lewis High School  High school
# 14551      26Q430  Francis Lewis High School  High school
# 14552      26Q430  Francis Lewis High School  High school
# 14553      26Q430  Francis Lewis High School  High school
# ...           ...                        ...          ...
# 194228     26Q430  Francis Lewis High School  High school
# 194229     26Q430  Francis Lewis High School  High school
# 194230     26Q430  Francis Lewis High School  High school
# ...

# %% [markdown]
# ## The hexbin below compares the distribution of the total number of people tested (Total  Tested) column against the Mean Score. We are able to see that average of the Mean Scores is between 55-70.

# %%
plot=sns.jointplot(df['Total Tested'], df['Mean Score'], kind='hex', joint_kws={'gridsize':50}, xlim=(6,800), ylim=(15,99))

# %% [markdown]
# ## Filter by Regents exam so I can analyze Regents exam citywide

# %%
df3=df[df['Regents Exam'] == 'U.S. History and Government']
df3
# Out:
#        School DBN                          School Name      School Level  \
# 47         01M292           Orchard Collegiate Academy       High school
# 48         01M292           Orchard Collegiate Academy       High school
# 49         01M292           Orchard Collegiate Academy       High school
# 93         01M448  University Neighborhood High School       High school
# 94         01M448  University Neighborhood High School       High school
# ...           ...                                  ...               ...
# 212215     84X703     Bronx Preparatory Charter School  Secondary School
# 212294     84X704          KIPP Academy Charter School   K-12 all grades
# 212295     84X704          KIPP Academy Charter School   K-12 all grades
# 212297     84X704          KIPP Academy Charter School   K-12 all grades
# 212300     84X704          KIPP Academy Charter School   K-12 all grades
#
#                        Regents Exam  Year  Total Tested  Mean Score  \
# ...

# %% [markdown]
# ## Groupby regents exam and year and filtered only by the max mean score for all schools citywide. Line 33 displays citywide information and it can be compared to line 34 displays which only shows FLHS information.

# %%
mscity=df3.groupby(['Regents Exam','Year'])['Mean Score'].max()

# %%
mscity
# Out:
# Regents Exam                 Year
# U.S. History and Government  2015    98.2
#                              2016    98.4
#                              2017    98.7
# Name: Mean Score, dtype: float64

# %%
ms
# Out:
# Regents Exam                 Year
# U.S. History and Government  2015    85.0
#                              2016    85.8
#                              2017    92.3
# Name: Mean Score, dtype: float64
